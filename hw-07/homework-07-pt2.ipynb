# %% [markdown]
# Scrape the content of https://www.lemonde.fr/Links to an external site. and save it as a CSV.
#
# We want: titles, subhead, article URL, whether it's premium or not, byline, article type, image URL.
#
# Bonus, if you want to get fancy:
#
# Make the CSV file auto-updating. Use this tutorial (videoLinks to an external site., textLinks to an external site.) but just ignore the visualization/datawrapper aspect
# Tips:
#
# Use the 02 - BBC Scraping.ipynb notebook as a guide for this one. We used .get('href', None) in class to avoid "the link doesn't exist" problems, but it uses try/except. Both are reasonable, but try/except is more flexible.
# You're going to be missing some article URLs - you should use try/except on them to avoid them being a problem, buuuut after that I would recommend printing the element to see why your approach isn't working (it's 100% possible to get all of the URLs!)
# If you want to make sure the element you're getting has a specific attribute, you can do something like .select_one("a[href]"). That will only give you anchor tags (links) that have hrefs.
# Instead of yes/no for the premium question, you can think of it as "put text in this column if the article is premium, don't put text in it if it is not"

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

response = requests.get("https://www.lemonde.fr/en/#")
doc = BeautifulSoup(response.text, 'html.parser')

# %%
items = doc.find_all('div', attrs={"class" : "article"})
len(items)
# Out:
# 25

# %%
rows = []
for item in items:
    print('======='*20)
    row = {}
    
    headline = item.find(class_="article__title").text.strip()
    row['headline'] = headline
    print(headline)

    subhead = item.find(class_="article__desc")
    if subhead is not None:
        subhead = subhead.text.strip()
        row['subhead'] = subhead
        print(subhead)
    else:
        subhead = None
        row['subhead'] = np.nan
        print("no subhead")

    byline = item.find(class_="article__byline")
    if byline is not None:
        byline = byline.text.strip()
        row['byline'] = byline
        print(byline)
    else:
        byline = 'Unknown'
        row['byline'] = byline
        print(byline)
        
    url = item.find('a').get('href', None)
    row['url'] = url
    print(url)

    article_type = item.find(class_='article__type')
    if article_type is not None:
        article_type = article_type.text.strip()
        row['article_type'] = article_type
        print(article_type)
    else:
        article_type = None
        row['article_type'] = np.nan
        print("no article type")

    premium = item.find(class_='sr-only')
    if premium is not None:
        premium = True
        row['premium'] = premium
        print("Premium?", premium)
    else:
        premium = False
        row['premium'] = False
        print("Premium?", premium)

    image_url = item.find(class_='article__media')
    if image_url is not None:
        image_url = image_url.find('img').get('src', None)
        row['image_url'] = image_url
        print(image_url)
    else:
        image_url = None
        row['image_url'] = image_url
        print("No image")

    rows.append(row)
# Out:
# ============================================================================================================================================
# New York and Paris mayors Mamdani and Grégoire meet to advocate for housing access and climate solutions
# Zohran Mamdani and Emmanuel Grégoire, the socialist mayors of New York and Paris, met in New York, using the opportunity to discuss shared interests in housing and environmental policy.
# Unknown
# https://www.lemonde.fr/en/politics/article/2026/09/20/new-york-and-paris-mayors-mamdani-and-gregoire-meet-to-advocate-for-housing-access-and-climate-solutions_6757742_5.html
# no article type
# Premium? True
# https://img.lemde.fr/2026/09/19/0/0/3000/2000/400/266/75/0/3ebd26c_upload-1-6panesduddr1-emmanuel-gregoire-x-zohran-mamdani-20260918-paola-chapdelaine-36.jpg
# ============================================================================================================================================
# Germany's far-right AfD celebrates another state election win
# no subhead
# Unknown
# https://www.lemonde.fr/en/international/article/2026/09/20/germans-vote-in-state-elections-threatening-fresh-blow-to-merz_6757733_4.html
# no article type
# Premium? False
# https://img.lemde.fr/2026/09/20/3/0/3808/2538/398/265/75/0/16d10b8_ftp-1-rdtyrimhuhb4-2026-09-20t163345z-1842270819-rc24nnailtfm-rtrmadp-3-germany-election-berlin-merz.JPG
# ============================================================================================================================================
# How concerned should we be about AI's supposed existential threat to humanity?
# no subhead
# Unknown
# https://www.lemonde.fr/en/pixels/article/2026/09/20/how-concerned-should-we-be-about-ai-s-supposed-existential-threat-to-humanity_6757739_13.html
# no article type
# Premium? True
# https://img.lemde.fr/2026/09
# ============================================================================================================================================
# Thousands march in Paris against bill granting police presumption of legitimate self defense
# no subhead
# Unknown
# https://www.lemonde.fr/en/france/article/2026/09/20/thousands-march-in-paris-against-bill-granting-police-presumption-of-legitimate-self-defense_6757740_7.html
# no article type
# Premium? False
# https://img.lemde.fr/2026/09/20/0/0/5286/3524/198/132/95/0/c3be3d6_ftp-1-tqelrzodtuqn-5136290-01-06.jpg
# ============================================================================================================================================
# Macron reaffirms French sovereignty over Saint Pierre and Miquelon against Trump's ambitions
# no subhead
# Unknown
# https://www.lemonde.fr/en/international/article/2026/09/20/macron-reaffirms-french-sovereignty-over-saint-pierre-and-miquelon-against-trump-s-ambitions_6757732_4.html
# no article type
# Premium? True
# No image
# ============================================================================================================================================
# Warren Buffett hands over $1 trillion financial empire to son
# no subhead
# Unknown
# https://www.lemonde.fr/en/international/article/2026/09/20/warren-buffett-hands-over-his-1-trillion-financial-empire-to-his-son_6757738_4.html
# no article type
# Premium? True
# No image
# ============================================================================================================================================
# North Korea fires two ballistic missiles into East Sea
# no subhead
# Unknown
# https://www.lemonde.fr/en/international/article/2026/09/20/north-korea-fires-two-projectiles-into-east-sea_6757734_4.html
# no article type
# Premium? False
# No image
# ============================================================================================================================================
# 'For a long time, French feminism had a problem with economics'
# no subhead
# Unknown
# https://www.lemonde.fr/en/money-investments/article/2026/09/20/titiou-lecoq-for-a-long-time-french-feminism-had-a-problem-with-economics_6757726_102.html
# no article type
# Premium? False
# No image
# ============================================================================================================================================
# Emma Heming Willis on her husband Bruce Willis's illness: 'Once I stopped being in denial, we've learned to just navigate the disease'
# no subhead
# Unknown
# https://www.lemonde.fr/en/intimacy/article/2026/09/19/emma-heming-willis-on-her-husband-bruce-willis-s-illness-once-i-stopped-being-in-denial-we-ve-learned-to-just-navigate-the-disease_6757720_310.html
# no article type
# Premium? True
# No image
# ============================================================================================================================================
# PSG president Nasser al-Khelaifi under investigation in France for conflict of interest
# no subhead
# Unknown
# https://www.lemonde.fr/en/sports/article/2026/09/20/psg-president-nasser-al-khelaifi-under-investigation-in-france-for-conflict-of-interest_6757736_9.html
# no article type
# Premium? False
# No image
# ============================================================================================================================================
# Paris's Techno Parade turns up volume to protest law targeting free parties
# no subhead
# Unknown
# https://www.lemonde.fr/en/culture/article/2026/09/20/paris-s-techno-parade-turns-up-volume-to-protest-law-targeting-free-parties_6757730_30.html
# no article type
# Premium? True
# No image
# ============================================================================================================================================
# Inside the Hamidovic clan's reign of terror over young female pickpockets in the Paris métro
# no subhead
# Unknown
# https://www.lemonde.fr/en/m-le-mag/article/2026/09/20/inside-the-hamidovic-clan-s-reign-of-terror-over-young-female-pickpockets-in-the-paris-metro_6757727_117.html
# no article type
# Premium? True
# No image
# ============================================================================================================================================
# A$AP Rocky, the rapper reinventing masculinity
# Like many of his peers, the superstar grew up amid poverty and violence. Yet he stands apart in the rap world, rejecting homophobia and misogyny. A Chanel ambassador who embraces being 'Mr. Rihanna', he is both an heir to the tradition of Black dandyism and the embodiment of a masculinity less bound by traditional norms.
# Clément Ghys
# https://www.lemonde.fr/en/m-le-mag/article/2026/09/19/a-ap-rocky-the-rapper-reinventing-masculinity_6757695_117.html
# Profile
# Premium? True
# https://img.lemde.fr/2026/09/15/179/74/1065/710/664/442/75/0/a475a51_ftp-1-jcdsxcvnlwy1-443595-3498582.jpg
# ============================================================================================================================================
# Macron, the 'pope-loving' president, faces strained relations with Vatican ahead of Leo XIV's Paris visit
# Ever since he first took office, Emmanuel Macron has placed great importance on his relationships with popes. His repeated invitations, breaches of protocol and displays of 'familiarity' have at times been seen as 'attempts to instrumentalize' the relationship.
# Sarah Belouezzane and  Solenn de Royer
# https://www.lemonde.fr/en/france/article/2026/09/19/macron-the-pope-loving-president-faces-strained-relations-with-the-vatican-ahead-of-leo-xiv-s-visit-to-paris_6757702_7.html
# In Depth
# Premium? True
# https://img.lemde.fr/2026/09/18/0/0/4500/3000/664/442/75/0/c4d9ee1_upload-1-9mbyetqgqbtj-lgeai-pape-macron-marseille082.jpg
# ============================================================================================================================================
# Saint Pierre and Miquelon, a pioneering example of climate change adaptation
# This year, residents of a town in the French overseas territory off the coast of Canada are set to move into a new village. This relocation, France's first planned effort to move an entire town, is the result of a lengthy process.
# Unknown
# https://www.lemonde.fr/en/environment/visuel/2026/05/04/saint-pierre-and-miquelon-a-pioneering-example-of-climate-change-adaptation_6753095_114.html
# Visual Story
# Premium? True
# https://img.lemde.fr/2026/02/27/250/0/1500/1000/664/442/75/0/c6f313c_upload-1-1idakhdkocff-spm-mediaappel.png
# ============================================================================================================================================
# French budget: PM Lecornu's precarious balancing act
# no subhead
# Unknown
# https://www.lemonde.fr/en/opinion/article/2026/09/19/french-budget-pm-lecornu-s-precarious-balancing-act_6757715_23.html
# Editorial
# Premium? False
# No image
# ============================================================================================================================================
# 'Just as we thought we were finally alone in an artificial world, the Earth responds to us with force'
# no subhead
# Unknown
# https://www.lemonde.fr/en/opinion/article/2026/09/16/just-as-we-thought-we-were-finally-alone-in-an-artificial-world-the-earth-responds-to-us-with-force_6757574_23.html
# Interview
# Premium? True
# No image
# ============================================================================================================================================
# 'Eco-anxiety is not only the result of the environmental crisis, but also stems from political inaction in the face of disaster'
# no subhead
# Unknown
# https://www.lemonde.fr/en/opinion/article/2026/09/14/eco-anxiety-is-not-only-the-result-of-the-environmental-crisis-but-also-stems-from-political-inaction-in-the-face-of-disaster_6757507_23.html
# Column
# Premium? True
# No image

# %%
# #trying again with try/except:

# rows = []
# for item in items[:3]:
#     print('======='*20)
#     row = {}
    
#     try:
#         row['headline'] = item.find(class_="article__title-label").text.strip()
#     except:
#         print("no headline found")

#     try:
#         row['subhead'] = item.find(class_="article__desc").text.strip()
#     except:
#         print("no subhead found")

#     try:
#         row['byline'] = item.find(class_="article__byline").text.strip()
#     except:
#         print("no byline found")

#     try:
#         row['url'] = item.find('a').get('href', None)
#     except:
#         print("no url found")
        
#     try:
#         row['article_type'] = item.find(class_='article__type').text.strip()
#     except:
#         print("no article_type found")   

#     try:
#         row['premium'] = item.find(class_='icon__premium')
#     except:
#         print("not premium") 

#     try:
#         row['image_url'] = item.find(class_='article__media').find('img').get('src', None)
#     except:
#         print("no image_url found") 

#     print(row)
#     rows.append(row)

# %% [markdown]
# try/except is not working but if/else is

# %%
rows
# Out:
# [{'headline': 'New York and Paris mayors Mamdani and Grégoire meet to advocate for housing access and climate solutions',
#   'subhead': 'Zohran Mamdani and Emmanuel Grégoire, the socialist mayors of New York and Paris, met in New York, using the opportunity to discuss shared interests in housing and environmental policy.',
#   'byline': 'Unknown',
#   'url': 'https://www.lemonde.fr/en/politics/article/2026/09/20/new-york-and-paris-mayors-mamdani-and-gregoire-meet-to-advocate-for-housing-access-and-climate-solutions_6757742_5.html',
#   'article_type': nan,
#   'premium': True,
#   'image_url': 'https://img.lemde.fr/2026/09/19/0/0/3000/2000/400/266/75/0/3ebd26c_upload-1-6panesduddr1-emmanuel-gregoire-x-zohran-mamdani-20260918-paola-chapdelaine-36.jpg'},
#  {'headline': "Germany's far-right AfD celebrates another state election win",
#   'subhead': nan,
#   'byline': 'Unknown',
#   'url': 'https://www.lemonde.fr/en/international/article/2026/09/20

#   'premium': True,
#   'image_url': 'https://img.lemde.fr/2026/09/18/0/0/4500/3000/664/442/75/0/c4d9ee1_upload-1-9mbyetqgqbtj-lgeai-pape-macron-marseille082.jpg'},
#  {'headline': 'Saint Pierre and Miquelon, a pioneering example of climate change adaptation',
#   'subhead': "This year, residents of a town in the French overseas territory off the coast of Canada are set to move into a new village. This relocation, France's first planned effort to move an entire town, is the result of a lengthy process.",
#   'byline': 'Unknown',
#   'url': 'https://www.lemonde.fr/en/environment/visuel/2026/05/04/saint-pierre-and-miquelon-a-pioneering-example-of-climate-change-adaptation_6753095_114.html',
#   'article_type': 'Visual Story',
#   'premium': True,
#   'image_url': 'https://img.lemde.fr/2026/02/27/250/0/1500/1000/664/442/75/0/c6f313c_upload-1-1idakhdkocff-spm-mediaappel.png'},
#  {'headline': "French budget: PM Lecornu's precarious balancing act",
#   'subhead': nan,
#   'byline': 'Unknown',
#   'url': 'https://www.lemonde.fr/en/opinion/article/2026/09/19/french-budget-pm-lecornu-s-precarious-balancing-act_6757715_23.html',
#   'article_type': 'Editorial',
#   'premium': False,
#   'image_url': None},
#  {'headline': "'Just as we thought we were finally alone in an artificial world, the Earth responds to us with force'",
#   'subhead': nan,
#   'byline': 'Unknown',
#   'url': 'https://www.lemonde.fr/en/opinion/article/2026/09/16/just-as-we-thought-we-were-finally-alone-in-an-artificial-world-the-earth-responds-to-us-with-force_6757574_23.html',
#   'article_type': 'Interview',
#   'premium': True,
#   'image_url': None},
#  {'headline': "'Eco-anxiety is not only the result of the environmental crisis, but also stems from political inaction in the face of disaster'",
#   'subhead': nan,
#   'byline': 'Unknown',
#   'url': 'https://www.lemonde.fr/en/opinion/article/2026/09/14/eco-anxiety-is-not-only-the-result-of-the-environmental-crisis-but-also-stems-from-political-inaction-in-the-face-of-disaster_6757507_23.html',
#   'article_type': 'Column',
#   'premium': True,
#   'image_url': None}]

# %%
df = pd.json_normalize(rows)
df.head()
# Out:
#                                             headline  \
# 0  New York and Paris mayors Mamdani and Grégoire...
# 1  Germany's far-right AfD celebrates another sta...
# 2  How concerned should we be about AI's supposed...
# 3  Macron says France and Canada 'great independe...
# 4  'Benjamin Netanyahu has literally sabotaged Is...
#
#                                              subhead   byline  \
# 0  Zohran Mamdani and Emmanuel Grégoire, the soci...  Unknown
# 1                                                NaN  Unknown
# 2                                                NaN  Unknown
# 3  During a joint news conference with Canadian l...  Unknown
# 4  The Foreign Ministry, which once stood at the ...  Unknown
#
#                                                  url article_type  premium  \
# 0  https://www.lemonde.fr/en/politics/article/202...          NaN     True
# 1  https://www.lemonde.fr/en/international/articl...          NaN    False
# 2  https://www.lemonde.fr/en/pixels/article/2026/...          NaN     True
# 3  https://www.lemonde.fr/en/international/articl...          NaN    False
# 4  https://www.lemonde.fr/en/international/articl...          NaN     True
#
#                                            image_url
# 0  https://img.lemde.fr/2026/09/19/0/0/3000/2000/...
# 1  https://img.lemde.fr/2026/09/20/3/0/3808/2538/...
# 2  https://img.lemde.fr/2026/09/18/0/0/3000/2000/...
# 3  https://img.lemde.fr/2026/09/20/0/85/2829/1886...
# 4  https://img.lemde.fr/2026/09/19/0/0/2390/1593/...

# %%
df.to_csv('lemonde_fr_news.csv', index=False)
