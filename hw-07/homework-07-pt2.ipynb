# %% [markdown]
# Scrape the content of https://www.lemonde.fr/Links to an external site. and save it as a CSV.
#
# We want: titles, subhead, article URL, whether it's premium or not, byline, article type, image URL.
#
# Bonus, if you want to get fancy:
#
# Make the CSV file auto-updating. Use this tutorial (videoLinks to an external site., textLinks to an external site.) but just ignore the visualization/datawrapper aspect
# Tips:
#
# Use the 02 - BBC Scraping.ipynb notebook as a guide for this one. We used .get('href', None) in class to avoid "the link doesn't exist" problems, but it uses try/except. Both are reasonable, but try/except is more flexible.
# You're going to be missing some article URLs - you should use try/except on them to avoid them being a problem, buuuut after that I would recommend printing the element to see why your approach isn't working (it's 100% possible to get all of the URLs!)
# If you want to make sure the element you're getting has a specific attribute, you can do something like .select_one("a[href]"). That will only give you anchor tags (links) that have hrefs.
# Instead of yes/no for the premium question, you can think of it as "put text in this column if the article is premium, don't put text in it if it is not"

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

response = requests.get("https://www.lemonde.fr/en/#")
doc = BeautifulSoup(response.text, 'html.parser')

# %%
items = doc.find_all('div', attrs={"class" : "article"})
len(items)
# Out:
# 25

# %%
rows = []
for item in items:
    print('======='*20)
    row = {}
    
    headline = item.find(class_="article__title").text.strip()
    row['headline'] = headline
    print(headline)

    subhead = item.find(class_="article__desc")
    if subhead is not None:
        subhead = subhead.text.strip()
        row['subhead'] = subhead
        print(subhead)
    else:
        subhead = None
        row['subhead'] = np.nan
        print("no subhead")

    byline = item.find(class_="article__byline")
    if byline is not None:
        byline = byline.text.strip()
        row['byline'] = byline
        print(byline)
    else:
        byline = 'Unknown'
        row['byline'] = byline
        print(byline)
        
    url = item.find('a').get('href', None)
    row['url'] = url
    print(url)

    article_type = item.find(class_='article__type')
    if article_type is not None:
        article_type = article_type.text.strip()
        row['article_type'] = article_type
        print(article_type)
    else:
        article_type = None
        row['article_type'] = np.nan
        print("no article type")

    premium = item.find(class_='sr-only')
    if premium is not None:
        premium = True
        row['premium'] = premium
        print("Premium?", premium)
    else:
        premium = False
        row['premium'] = False
        print("Premium?", premium)

    image_url = item.find(class_='article__media')
    if image_url is not None:
        image_url = image_url.find('img').get('src', None)
        row['image_url'] = image_url
        print(image_url)
    else:
        image_url = None
        row['image_url'] = image_url
        print("No image")

    rows.append(row)
# Out:
# ============================================================================================================================================
# Poll: Le Pen begins presidential campaign in strongest position ever amid worried, angry electorate
# In France's polarized political landscape, Marine Le Pen of the far-right Rassemblement National is enjoying unprecedented support, and radical left candidate Jean-Luc Mélenchon is building a strong base. Wide open for other candidates, the race is drawing significant interest from voters concerned about the future, Le Monde's first poll shows.
# Unknown
# https://www.lemonde.fr/en/politics/article/2026/09/13/2027-presidential-election-le-pen-begins-campaign-in-strongest-position-ever-amid-worried-angry-electorate_6757478_5.html
# no article type
# Premium? True
# https://img.lemde.fr/2026/09/13/0/0/1801/1200/400/266/75/0/c581100_upload-1-d4128sjzhbut-cevipof-sept2026-lmiappel-1.png
# ============================================================================================================================================
# 'When you're that sick, you reflect on the values that matter most': Sweden's Birgitta Ohlsson returns to fight the far right
# no subhead
# Unknown
# https://www.lemonde.fr/en/m-le-mag/article/2026/09/13/when-you-re-that-sick-you-reflect-on-the-values-that-matter-most-sweden-s-birgitta-ohlsson-returns-to-fight-the-far-right_6757468_117.html
# no article type
# Premium? True
# https://img.lemde.fr/2026/09/08/0/1/1498/999/398/265/75/0/3ff2b47_ftp-1-x4ir0n5fhips-441656-3495799.jpg
# ============================================================================================================================================
# Sweden's election too close to call as far right loses ground
# no subhead
# Unknown
# https://www.lemonde.fr/en/international/article/2026/09/13
html
# no article type
# Premium? False
# https://img.lemde.fr/2026/09/13/1/0/8192/5461/198/132/95/0/a98c9ed_ftp-1-zbwx0a3u1hm1-df354409a64a4c20b890d34ec0232581-0-7ccdf7ecdcde47c1889263099a041d36.jpg
# ============================================================================================================================================
# 2027 presidential election: Raphaël Glucksmann touts his 'environmental revolution' candidacy
# no subhead
# Unknown
# https://www.lemonde.fr/en/les-decodeurs/article/2026/09/13/2027-presidential-election-raphael-glucksmann-touts-his-environmental-revolution-candidacy_6757473_8.html
# no article type
# Premium? True
# https://img.lemde.fr/2026/08/23/0/0/6585/4390/198/132/95/0/4bef334_ftp-1-cztew9mq9ev0-5906047-01-06.jpg
# ============================================================================================================================================
# Céline Dion returns to stage for first Paris show: 'I want to sing for you, to sing about life'
# no subhead
# Unknown
# https://www.lemonde.fr/en/culture/article/2026/09/13/celine-dion-returns-to-stage-for-first-paris-show-i-want-to-sing-for-you-to-sing-about-life_6757465_30.html
# no article type
# Premium? True
# https://img.lemde.fr/2026/09/12/0/0/7047/4698/198/132/95/0/4616786_ftp-1-iips0d1veika-5071445-01-06.jpg
# ============================================================================================================================================
# In southeast France, the deaths of 64 sheep blamed on wolves raise questions
# no subhead
# Unknown
# https://www.lemonde.fr/en/environment/article/2026/09/13/in-southeast-france-the-deaths-of-64-sheep-blamed-on-wolves-raise-questions_6757472_114.html
# no article type
# Premium? True
# No image
# ============================================================================================================================================
# France public radio staff strike over commentator from far-right weekly
# no subhead
# Unknown
# https://www.lemonde.fr/en/france/article/2026/09/13/france-public-radio-staff-strike-over-commentator-from-far-right-weekly_6757476_7.html
# no article type
# Premium? False
# No image
# ============================================================================================================================================
# Macron, Carney to visit French islands after Trump's map post
# no subhead
# Unknown
# https://www.lemonde.fr/en/international/article/2026/09/13/macron-carney-to-visit-french-islands-after-trump-s-map-post_6757469_4.html
# no article type
# Premium? False
# No image
# ============================================================================================================================================
# 'Ordinary citizens do not want to be sent to a war with no end in sight': Russian men consider exile
# no subhead
# Unknown
# https://www.lemonde.fr/en/international/article/2026/09/13/ordinary-citizens-do-not-want-to-be-sent-to-a-war-with-no-end-in-sight-russian-men-consider-exile_6757464_4.html
# no article type
# Premium? True
# No image
# ============================================================================================================================================
# France issues discreet apology to lift US block on new ambassador to Washington
# no subhead
# Unknown
# https://www.lemonde.fr/en/international/article/2026/09/13/france-issues-discreet-apology-to-lift-us-block-on-new-ambassador-to-washington_6757471_4.html
# no article type
# Premium? True
# No image
# ============================================================================================================================================
# 2027 presidential election: Mélenchon pressures left-wing rivals at Fête de L'Humanité festival
# no subhead
# Unknown
# https://www.lemonde.fr/en/politics/article/2026/09/13/2027-presidential-election-melenchon-pressures-left-wing-rivals-at-fete-de-l-humanite-festival_6757466_5.html
# no article type
# Premium? True
# No image
# ============================================================================================================================================
# 'Flying taxis' enter critical phase of industrial reality after decade of extravagant promises
# no subhead
# Unknown
# https://www.lemonde.fr/en/economy/article/2026/09/13/flying-taxis-enter-a-critical-phase-of-industrial-reality-after-a-decade-of-extravagant-promises_6757461_19.html
# no article type
# Premium? True
# No image
# ============================================================================================================================================
# Former Greek prison island of Gyaros becomes biodiversity haven
# no subhead
# Unknown
# https://www.lemonde.fr/en/environment/article/2026/09/13/former-greek-prison-island-of-gyaros-becomes-biodiversity-haven_6757459_114.html
# no article type
# Premium? True
# No image
# ============================================================================================================================================
# 25 French jihadists held in Iraq appeal to EU human rights court for repatriation
# The Islamic State group members had been quietly transferred from Syria to Iraq, where they could face the death penalty. Their lawyers say Paris's refusal to prosecute them in France undermines the rule of law and opens to arbitrary decisions by the authorities.
# Soren Seelow
# https://www.lemonde.fr/en/france/article/2026/09/12/25-french-jihadists-held-in-iraq-appeal-to-eu-human-rights-court-for-repatriation_6757452_7.html
# In Depth
# Premium? True
# https://img.lemde.fr/2026/09/11/0/0/6120/4080/664/442/75/0/4b00830_upload-1-vqyrx3exiib2-ap26043744766520.jpg
# ============================================================================================================================================
# 2027 presidential election: Bruno Retailleau takes free-market approach to climate change
# Candidates and the climate (2/5). The conservative candidate criticizes what he called 'paralyzing regulations' that he said were preventing climate change. He champions nuclear power, geothermal energy and the construction of large water reservoirs used for agricultural irrigation, despite the limitations of these measures.
# William Audureau
# https://www.lemonde.fr/en/les-decodeurs/article/2026/09/12/2027-presidential-election-bruno-retailleau-takes-a-free-market-approach-to-climate-change_6757451_8.html
# In Depth
# Premium? True
# https://img.lemde.fr/2026/06/22/0/0/6048/4032/664/442/75/0/e9040fd_ftp-1-m9w133qvpk23-5406287-01-06.jpg
# ============================================================================================================================================
# The forgotten French prisoner of 9/11
# Zacarias Moussaoui, who was sent to the US by Al-Qaeda to prepare attacks and was convicted of complicity in the September 11 attacks, has spent the past 20 years serving a life sentence without the possibility of parole in a high-security penitentiary in Colorado. His lawyer is requesting his transfer to France.
# Christophe Ayad
# https://www.lemonde.fr/en/international/article/2026/09/11/the-forgotten-french-prisoner-of-9-11_6757404_4.html
# In Depth
# Premium? True
# https://img.lemde.fr/2026/09/09/1127/0/3862/2574/664/442/75/0/94905ac_upload-1-m9rvlsyrelm7-rea11638613.jpg
# ============================================================================================================================================
# Thomas Piketty: 'To solve today's contradictions, we must rethink prosperity while respecting planetary boundaries'
# no subhead
# Unknown
# https://www.lemonde.fr/en/opinion/article/2026/09/12/thomas-piketty-to-solve-today-s-contradictions-we-must-rethink-prosperity-while-respecting-planetary-boundaries_6757444_23.html
# Column
# Premium? True
# No image
# ============================================================================================================================================
# Space: A test of Europe's power
# no subhead
# Unknown
# https://www.lemonde.fr/en/opinion/article/2026/09/09/space-a-test-of-power-for-europe_6757341_23.html
# Editorial
# Premium? False
# No image
# ============================================================================================================================================
# The legitimate and imperative sanctioning of Israeli settlements
# no subhead
# Unknown
# https://www.lemonde.fr/en/opinion/article/2026/09/11/the-legitimate-and-imperative-sanctioning-of-israeli-settlements_6757424_23.html
# Editorial
# Premium? False
# No image

# %%
# #trying again with try/except:

# rows = []
# for item in items[:3]:
#     print('======='*20)
#     row = {}
    
#     try:
#         row['headline'] = item.find(class_="article__title-label").text.strip()
#     except:
#         print("no headline found")

#     try:
#         row['subhead'] = item.find(class_="article__desc").text.strip()
#     except:
#         print("no subhead found")

#     try:
#         row['byline'] = item.find(class_="article__byline").text.strip()
#     except:
#         print("no byline found")

#     try:
#         row['url'] = item.find('a').get('href', None)
#     except:
#         print("no url found")
        
#     try:
#         row['article_type'] = item.find(class_='article__type').text.strip()
#     except:
#         print("no article_type found")   

#     try:
#         row['premium'] = item.find(class_='icon__premium')
#     except:
#         print("not premium") 

#     try:
#         row['image_url'] = item.find(class_='article__media').find('img').get('src', None)
#     except:
#         print("no image_url found") 

#     print(row)
#     rows.append(row)

# %% [markdown]
# try/except is not working but if/else is

# %%
rows
# Out:
# [{'headline': 'Poll: Le Pen begins presidential campaign in strongest position ever amid worried, angry electorate',
#   'subhead': "In France's polarized political landscape, Marine Le Pen of the far-right Rassemblement National is enjoying unprecedented support, and radical left candidate Jean-Luc Mélenchon is building a strong base. Wide open for other candidates, the race is drawing significant interest from voters concerned about the future, Le Monde's first poll shows.",
#   'byline': 'Unknown',
#   'url': 'https://www.lemonde.fr/en/politics/article/2026/09/13/2027-presidential-election-le-pen-begins-campaign-in-strongest-position-ever-amid-worried-angry-electorate_6757478_5.html',
#   'article_type': nan,
#   'premium': True,
#   'image_url': 'https://img.lemde.fr/2026/09

#   'premium': True,
#   'image_url': 'https://img.lemde.fr/2026/09/11/0/0/6120/4080/664/442/75/0/4b00830_upload-1-vqyrx3exiib2-ap26043744766520.jpg'},
#  {'headline': '2027 presidential election: Bruno Retailleau takes free-market approach to climate change',
#   'subhead': "Candidates and the climate (2/5). The conservative candidate criticizes what he called 'paralyzing regulations' that he said were preventing climate change. He champions nuclear power, geothermal energy and the construction of large water reservoirs used for agricultural irrigation, despite the limitations of these measures.",
#   'byline': 'William Audureau',
#   'url': 'https://www.lemonde.fr/en/les-decodeurs/article/2026/09/12/2027-presidential-election-bruno-retailleau-takes-a-free-market-approach-to-climate-change_6757451_8.html',
#   'article_type': 'In Depth',
#   'premium': True,
#   'image_url': 'https://img.lemde.fr/2026/06/22/0/0/6048/4032/664/442/75/0/e9040fd_ftp-1-m9w133qvpk23-5406287-01-06.jpg'},
#  {'headline': 'The forgotten French prisoner of 9/11',
#   'subhead': 'Zacarias Moussaoui, who was sent to the US by Al-Qaeda to prepare attacks and was convicted of complicity in the September 11 attacks, has spent the past 20 years serving a life sentence without the possibility of parole in a high-security penitentiary in Colorado. His lawyer is requesting his transfer to France.',
#   'byline': 'Christophe Ayad',
#   'url': 'https://www.lemonde.fr/en/international/article/2026/09/11/the-forgotten-french-prisoner-of-9-11_6757404_4.html',
#   'article_type': 'In Depth',
#   'premium': True,
#   'image_url': 'https://img.lemde.fr/2026/09/09/1127/0/3862/2574/664/442/75/0/94905ac_upload-1-m9rvlsyrelm7-rea11638613.jpg'},
#  {'headline': "Thomas Piketty: 'To solve today's contradictions, we must rethink prosperity while respecting planetary boundaries'",
#   'subhead': nan,
#   'byline': 'Unknown',
#   'url': 'https://www.lemonde.fr/en/opinion/article/2026/09/12/thomas-piketty-to-solve-today-s-contradictions-we-must-rethink-prosperity-while-respecting-planetary-boundaries_6757444_23.html',
#   'article_type': 'Column',
#   'premium': True,
#   'image_url': None},
#  {'headline': "Space: A test of Europe's power",
#   'subhead': nan,
#   'byline': 'Unknown',
#   'url': 'https://www.lemonde.fr/en/opinion/article/2026/09/09/space-a-test-of-power-for-europe_6757341_23.html',
#   'article_type': 'Editorial',
#   'premium': False,
#   'image_url': None},
#  {'headline': 'The legitimate and imperative sanctioning of Israeli settlements',
#   'subhead': nan,
#   'byline': 'Unknown',
#   'url': 'https://www.lemonde.fr/en/opinion/article/2026/09/11/the-legitimate-and-imperative-sanctioning-of-israeli-settlements_6757424_23.html',
#   'article_type': 'Editorial',
#   'premium': False,
#   'image_url': None}]

# %%
df = pd.json_normalize(rows)
df.head()
# Out:
#                                             headline  \
# 0  Poll: Le Pen begins presidential campaign in s...
# 1  'When you're that sick, you reflect on the val...
# 2  Sweden's election too close to call as far rig...
# 3  Political scientist Julia Reuschenbach: 'I do ...
# 4  US wins fifth straight women's FIBA World Cup ...
#
#                                              subhead   byline  \
# 0  In France's polarized political landscape, Mar...  Unknown
# 1                                                NaN  Unknown
# 2                                                NaN  Unknown
# 3  Following the Alternative for Germany (AfD) vi...  Unknown
# 4  The US team overcame a rocky start and dominat...  Unknown
#
#                                                  url article_type  premium  \
# 0  https://www.lemonde.fr/en/politics/article/202...          NaN     True
# 1  https://www.lemonde.fr/en/m-le-mag/article/202...          NaN     True
# 2  https://www.lemonde.fr/en/international/articl...          NaN    False
# 3  https://www.lemonde.fr/en/international/articl...          NaN     True
# 4  https://www.lemonde.fr/en/sports/article/2026/...          NaN    False
#
#                                            image_url
# 0  https://img.lemde.fr/2026/09/13/0/0/1801/1200/...
# 1  https://img.lemde.fr/2026/09/08/0/1/1498/999/3...
# 2  https://img.lemde.fr/2026/09/13/0/0/5623/3749/...
# 3  https://img.lemde.fr/2026/09/07/0/47/5260/3507...
# 4  https://img.lemde.fr/2026/09/13/148/0/5047/336...

# %%
df.to_csv('lemonde_fr_news.csv', index=False)
